# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Data_Train.xlsx')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (10683, 11)

# %%
source =df['Source']

# %%
source
# Out:
# 0        Banglore
# 1         Kolkata
# 2           Delhi
# 3         Kolkata
# 4        Banglore
#            ...
# 10678     Kolkata
# 10679     Kolkata
# 10680    Banglore
# 10681    Banglore
# 10682       Delhi
# Name: Source, Length: 10683, dtype: object

# %%
null_source = source.isnull()

# %%
null_source
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680    False
# 10681    False
# 10682    False
# Name: Source, Length: 10683, dtype: bool

# %%
for item in df:
    print(df[item].values)
# Out:
# ['IndiGo' 'Air India' 'Jet Airways' ... 'Jet Airways' 'Vistara'
#  'Air India']
# ['24/03/2019' '1/05/2019' '9/06/2019' ... '27/04/2019' '01/03/2019'
#  '9/05/2019']
# ['Banglore' 'Kolkata' 'Delhi' ... 'Banglore' 'Banglore' 'Delhi']
# ['New Delhi' 'Banglore' 'Cochin' ... 'Delhi' 'New Delhi' 'Cochin']
# ['BLR → DEL' 'CCU → IXR → BBI → BLR' 'DEL → LKO → BOM → COK' ...
#  'BLR → DEL' 'BLR → DEL' 'DEL → GOI → BOM → COK']
# ['22:20' '05:50' '09:25' ... '08:20' '11:30' '10:55']
# ['01:10 22 Mar' '13:15' '04:25 10 Jun' ... '11:20' '14:10' '19:15']
# ['2h 50m' '7h 25m' '19h' ... '3h' '2h 40m' '8h 20m']
# ['non-stop' '2 stops' '2 stops' ... 'non-stop' 'non-stop' '2 stops']
# ['No info' 'No info' 'No info' ... 'No info' 'No info' 'No info']
# [ 3897  7662 13882 ...  7229 12648 11753]

# %%
Determine the number of cells with no values
# Out:
#   File "<ipython-input-21-a28772cfa576>", line 1
#     Determine the number of cells with no values
#               ^
# SyntaxError: invalid syntax

# %%
#

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#Drop missing values
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
def change_to_datetime(col):
    df[col]=pd.to_datetime(df[col])

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
for i in ['Date_of_Journey', 'Dep_Time', 'Arrival_Time']:
    change_to_datetime(i)

# %%
df.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
df['Journey_day']=df['Date_of_Journey'].dt.day
df['Journey_month']=df['Date_of_Journey'].dt.month

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-01-05   Kolkata    Banglore
# 2      Jet Airways      2019-09-06     Delhi      Cochin
# 3           IndiGo      2019-12-05   Kolkata    Banglore
# 4           IndiGo      2019-01-03  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-01-03  Banglore   New Delhi
# 10682    Air India      2019-09-05     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2021-08-01 22:20:00 2021-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2021-08-01 05:50:00 2021-08-01 13:15:00   7h 25m
# ...

# %%
df.drop('journey_day',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-5eb2da2c41d8> in <module>
# ----> 1 df.drop('journey_day',axis=1,inplace=True)
#
# c:\users\tee_f\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\users\tee_f\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-01-05   Kolkata    Banglore
# 2      Jet Airways      2019-09-06     Delhi      Cochin
# 3           IndiGo      2019-12-05   Kolkata    Banglore
# 4           IndiGo      2019-01-03  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-01-03  Banglore   New Delhi
# 10682    Air India      2019-09-05     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2021-08-01 22:20:00 2021-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2021-08-01 05:50:00 2021-08-01 13:15:00   7h 25m
# ...

# %%
df.drop('jounney_month',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-6b4a4391b2a0> in <module>
# ----> 1 df.drop('jounney_month',axis=1,inplace=True)
#
# c:\users\tee_f\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\users\tee_f\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df.drop('jouney_month', axis=1, inplace=True)

# %%
df.drop('Jounney_month', axis=1, inplace=True)

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-01-05   Kolkata    Banglore
# 2      Jet Airways      2019-09-06     Delhi      Cochin
# 3           IndiGo      2019-12-05   Kolkata    Banglore
# 4           IndiGo      2019-01-03  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-01-03  Banglore   New Delhi
# 10682    Air India      2019-09-05     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2021-08-01 22:20:00 2021-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2021-08-01 05:50:00 2021-08-01 13:15:00   7h 25m
# ...

# %%
def extract_hour(df, col):
    df[col+'_hour'] =df[col].dt.hour
def extract_min(df, col):
    df[col+'_minute'] =df[col].dt.minute
def drop_column(df, col):
    df.drop(col, axis=1, inplace=True)

# %%
extract_hour(df, 'Dep_Time')
extract_min(df, 'Dep_Time')
drop_column(df, 'Dep_Time')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#          Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0 2021-03-22 01:10:00   2h 50m    non-stop         No info   3897
# 1 2021-08-01 13:15:00   7h 25m     2 stops         No info   7662
# 2 2021-06-10 04:25:00      19h     2 stops         No info  13882
# 3 2021-08-01 23:30:00   5h 25m      1 stop         No info   6218
# 4 2021-08-01 21:35:00   4h 45m      1 stop         No info  13302
#
#    Journey_day  Journey_month  Dep_Time_hour  Dep_Time_minute
# ...

# %%
extract_hour(df, 'Arrival_Time')
extract_min(df, 'Arrival_Time')
drop_column(df, 'Arrival_Time')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            5              1
# 2      19h     2 stops         No info  13882            6              9
# 3   5h 25m      1 stop         No info   6218            5             12
# 4   4h 45m      1 stop         No info  13302            3              1
#
# ...

# %%
df['Duration'] = duration

# %%
print(type(df['Duration']))
duration = list(df['Duration'])
for i in range(len(duration)):
    if len(duration[i].split(' ')) == 2:
           pass
    else:
        if 'h' in duration[i]:
            duration[i] =duration[i] + ' 0m'
        else:
           duration[i] ='0h ' + duration[i]
# Out:
# <class 'pandas.core.series.Series'>

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month  \
# 0   2h 50m    non-stop         No info   3897           24              3
# 1   7h 25m     2 stops         No info   7662            5              1
# 2    19h0m     2 stops         No info  13882            6              9
# 3   5h 25m      1 stop         No info   6218            5             12
# 4   4h 45m      1 stop         No info  13302            3              1
#
# ...
